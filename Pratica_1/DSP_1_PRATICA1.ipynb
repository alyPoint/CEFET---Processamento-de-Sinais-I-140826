# %% [markdown]
# <a href="https://colab.research.google.com/github/alyPoint/CEFET---Processamento-de-Sinais-I-140826/blob/main/DSP_1_PRATICA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1

# %%
#TESTE

import numpy as np
import matplotlib.pyplot as plt

#t = np.linspace(0, 5, 500)

arr = np.arange (0, 5, 1/44100, dtype = float)
y = np.cos(2*np.pi * arr)

plt.plot(arr, y)
plt.show()

# %%
#500 Herts

import numpy as np
import matplotlib.pyplot as plt

t = np.arange (0, 0.005, 1/44100, dtype = float)
y = np.cos(2*np.pi * 500 * t)

plt.plot(t, y)
plt.show()

# %%
#5000 Herts

import numpy as np
import matplotlib.pyplot as plt

t = np.arange (0, 0.005, 1/44100, dtype = float)
y = np.cos(2*np.pi * 5000 * t)

plt.plot(t, y)
plt.show()

# %%
#10000 Herts

import numpy as np
import matplotlib.pyplot as plt

t = np.arange (0, 0.005, 1/44100, dtype = float)
y = np.cos(2*np.pi * 10000 * t)

plt.plot(t, y)
plt.show()
